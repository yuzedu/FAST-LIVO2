# %% [markdown]
# <a href="https://colab.research.google.com/github/yuzedu/FAST-LIVO2/blob/main/gaussian_splatting_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive
# !git clone --recursive https://github.com/camenduru/gaussian-splatting
# !pip install -q plyfile
# Out:
# /content/drive/MyDrive
# Cloning into 'gaussian-splatting'...
# remote: Enumerating objects: 603, done.
# remote: Total 603 (delta 0), reused 0 (delta 0), pack-reused 603 (from 1)
# Receiving objects: 100% (603/603), 2.09 MiB | 12.18 MiB/s, done.
# Resolving deltas: 100% (344/344), done.
# Submodule 'SIBR_viewers' (https://gitlab.inria.fr/sibr/sibr_core) registered for path 'SIBR_viewers'
# Submodule 'submodules/diff-gaussian-rasterization' (https://github.com/graphdeco-inria/diff-gaussian-rasterization) registered for path 'submodules/diff-gaussian-rasterization'
# Submodule 'submodules/simple-knn' (https://gitlab.inria.fr/bkerbl/simple-knn.git) registered for path 'submodules/simple-knn'
# Cloning into '/content/drive/MyDrive/gaussian-splatting/SIBR_viewers'...
# ...
# remote: Enumerating objects: 3293, done.
# remote: Counting objects: 100% (322/322), done.
# remote: Compressing objects: 100% (174/174), done.
# ...

# %%
# %cd  /content/drive/MyDrive/gaussian-splatting
# !pip install -q /content/gaussian-splatting/submodules/diff-gaussian-rasterization
# Out:
# /content/drive/MyDrive/gaussian-splatting
#   Preparing metadata (setup.py) ... done
# ...

# %%
# Patch simple_knn.cu to include <cfloat> for FLT_MAX definition
# !sed -i '1i#include <cfloat>' submodules/simple-knn/simple_knn.cu

# Re-attempt installation with --no-build-isolation
# !pip install submodules/simple-knn --no-build-isolation

# Verify installation
# !python -c "import simple_knn; print('simple_knn installed successfully')"
# Out:
# Processing ./submodules/simple-knn
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for simple_knn: filename=simple_knn-0.0.0-cp312-cp312-linux_x86_64.whl size=3498342 sha256=890871063aa7c620e5d822e5fccad3e6be9780d77187a6abaec05933e23dfe2d
#   Stored in directory: /root/.cache/pip/wheels/6c/18/64/47b03cfe9c6dea8c51648608c52a0b81c52fda8cf53ab05819
# Successfully built simple_knn
# ...
#   Attempting uninstall: simple_knn
#     Found existing installation: simple_knn 0.0.0
#     Uninstalling simple_knn-0.0.0:
#       Successfully uninstalled simple_knn-0.0.0
# ...
# simple_knn installed successfully

# %%
# !wget https://huggingface.co/camenduru/gaussian-splatting/resolve/main/tandt_db.zip
# !unzip tandt_db.zip

# !python train.py -s /content/drive/MyDrive/gaussian-opacity-fields/table_01_masked_ds5x
# Out:
# 2026-02-10 23:05:28.330111: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-02-10 23:05:28.347605: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1770764728.369425    9455 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1770764728.376650    9455 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...
